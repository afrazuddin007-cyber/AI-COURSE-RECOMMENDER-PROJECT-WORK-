# %% [markdown]
# LOADING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.5.0-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.5.0

# %% [markdown]
# MODULE 0
# Loading Groq

# %%
from google.colab import userdata
import os
from groq import Groq

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

print("Setup OK:", os.environ["GROQ_API_KEY"][:4])

client = Groq()
# Out:
# Setup OK: gsk_

# %% [markdown]
# MODEL 0: Testing Groq

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models"
        }
    ],
    model="llama-3.3-70b-versatile"
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial for various applications and industries, and their importance can be understood from several perspectives:
#
# 1. **Improved User Experience**: Fast language models enable faster response times, making interactions with chatbots, virtual assistants, and other language-based interfaces more seamless and efficient. This leads to a better user experience, increased satisfaction, and higher engagement.
# 2. **Real-Time Applications**: Fast language models are essential for real-time applications, such as:
# 	* Live chat support: Quick responses help resolve customer queries and issues promptly.
# 	* Voice assistants: Fast language processing enables voice assistants to understand and respond to voice commands rapidly.
# 	* Live translation: Fast language models facilitate real-time translation, allowing people to communicate across languages.
# 3. **Efficient Processing of Large Datasets**: Fast language models can process vast amounts of text data quickly, making them ideal for applications that require:
# 	* Text analysis: Rapid analysis of large datasets for insights, trends, and patterns.
# 	* Sentiment analysis: Quick sentiment analysis to gauge public opinion, sentiment, and emotions.
# 	* Information retrieval: Fast search and retrieval of relevant information from large text collections.
# 4. **Enhanced Productivity and Automation**: Fast language models can automate tasks, such as:
# 	* Text generation: Automatic generation of text, like chatbot responses, emails, or articles.
# 	* Data entry: Automated data entry, reducing manual labor and increasing accuracy.
# 	* Document processing: Quick processing and analysis of documents, like contracts, reports, or invoices.
# 5. **Competitive Advantage**: Organizations that leverage fast language models can gain a competitive advantage by:
# 	* Responding quickly to customer inquiries and issues.
# 	* Analyzing large datasets to inform business decisions.
# 	* Developing innovative products and services that rely on fast language processing.
# 6. **Research and Development**: Fast language models accelerate research and development in areas like:
# 	* Natural Language Processing (NLP): Faster models enable researchers to explore new NLP techniques, models, and applications.
# 	* Artificial Intelligence (AI): Fast language models contribute to the development of more sophisticated AI systems.
# 7. **Edge Computing and IoT**: Fast language models are essential for edge computing and IoT applications, where:
# 	* Low-latency processing is critical for real-time decision-making.
# 	* Limited computational resources require efficient language processing.
#
# In summary, fast language models are vital for delivering exceptional user experiences, driving business efficiency, and enabling innovation in various industries. Their importance will continue to grow as language-based applications become increasingly ubiquitous and critical to our daily lives.

# %% [markdown]
# LOADING THE COURSE DATASET

# %%
course=pd.read_csv('/content/coursera_course_dataset_v3.csv')

# %% [markdown]
# PRINTING THE FIRST 5 ROWS

# %%
course.head()
# Out:
#                                    Title Organization  \
# 0                   Google Cybersecurity       Google
# 1                  Google Data Analytics       Google
# 2             Google Project Management:       Google
# 3                       IBM Data Science          IBM
# 4  Google Digital Marketing & E-commerce       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        Type      Duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %% [markdown]
# We drop the unnamed column as it is of no use

# %%
course.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
course.head()
# Out:
#                                    Title Organization  \
# 0                   Google Cybersecurity       Google
# 1                  Google Data Analytics       Google
# 2             Google Project Management:       Google
# 3                       IBM Data Science          IBM
# 4  Google Digital Marketing & E-commerce       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        Type      Duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %%
course.columns
# Out:
# Index(['Title', 'Organization', 'Skills', 'Ratings', 'course_url',
#        'course_students_enrolled', 'course_description', 'Review Count',
#        'Difficulty', 'Type', 'Duration'],
#       dtype='object')

# %%
course.columns=course.columns.str.lower()

# %%
course.head()
# Out:
#                                    title organization  \
# 0                   Google Cybersecurity       Google
# 1                  Google Data Analytics       Google
# 2             Google Project Management:       Google
# 3                       IBM Data Science          IBM
# 4  Google Digital Marketing & E-commerce       Google
#
#                                               skills  ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description review count difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        type      duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %%
#print rows and columns
course.shape
# Out:
# (623, 11)

# %% [markdown]
# The data has 623 rows and 11 columns

# %%
role_skills={'Data Scientist': ['python', 'statistics', 'machine learning', 'sql',
                           'data visualization', 'deep learning'], 'Data Analyst': ['excel', 'sql', 'statistics', 'data visualization', 'python'], 'ML Engineer':['python', 'machine learning', 'deep learning, sql', 'cloud'],'Data Engineer': ['python','sql', 'data wrangling', 'cloud', 'big data', 'apis'], 'Business Analyst': ['excel', 'sql', 'statistics', 'data visualization',
                           'communication'],'BI Developer': ['sql', 'data visualization', 'excel', 'statistics', 'power bi'],'AI Researcher':['python', 'deep learning', 'machine learning',
                           'mathematics', 'nlp'], 'Backend Developer': ['python', 'sql', 'apis', 'cloud', 'git'],'MLOps Engineer':['python', 'machine learning', 'cloud', 'docker', 'mlops'], 'NLP Engineer':['python', 'machine learning', 'deep learning', 'nlp',
                           'statistics']



}

# %%
role_skills['Data Scientist']
# Out:
# ['python',
#  'statistics',
#  'machine learning',
#  'sql',
#  'data visualization',
#  'deep learning']

# %%
course.isnull().sum()
# Out:
# title                         0
# organization                  0
# skills                        0
# ratings                       0
# course_url                  220
# course_students_enrolled    236
# course_description          221
# review count                  0
# difficulty                    0
# type                          0
# duration                      0
# dtype: int64

# %%
course.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicates as such

# %%
course.drop(columns=['course_url' ,	'course_students_enrolled' ,'course_description', 'review count'],axis=1,inplace=True)

# %%
course.head()
# Out:
#                                    title organization  \
# 0                   Google Cybersecurity       Google
# 1                  Google Data Analytics       Google
# 2             Google Project Management:       Google
# 3                       IBM Data Science          IBM
# 4  Google Digital Marketing & E-commerce       Google
#
#                                               skills  ratings difficulty  \
# 0   Network Security, Python Programming, Linux, ...      4.8   Beginner
# 1   Data Analysis, R Programming, SQL, Business C...      4.8   Beginner
# 2   Project Management, Strategy and Operations, ...      4.8   Beginner
# 3   Python Programming, Data Science, Machine Lea...      4.6   Beginner
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8   Beginner
#
#                        type      duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %%
course.shape
# Out:
# (623, 7)
